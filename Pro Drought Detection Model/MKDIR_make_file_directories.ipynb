# %%
import os

# Base directory where the folders will be created
base_dir = "data_v03\sequence_data_v03"

# Ensure the base directory exists
os.makedirs(base_dir, exist_ok=True)

# List of region names
region_names = [
    "BRB", "CHC", "CQC", "CYP", "DEU", "EIU",
    "GUP", "MGD", "MUL", "NET", "NWH",
    "SEQ", "WET"
] 

# Create directories for each region
for region in region_names:
    region_dir = os.path.join(base_dir, region.replace(" ", "_"))
    os.makedirs(region_dir, exist_ok=True)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Jspch\AppData\Local\Temp\ipykernel_31064\708004398.py:4: SyntaxWarning: invalid escape sequence '\s'
#   base_dir = "data_v03\sequence_data_v03"
