qld.nc
# ✅ Cropped 2023.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Mulga_Lands\2023.vp_deficit_Mulga_Lands_qld.nc

# %%
# Paths
input_dir = r'Data\Data for SPI\Vapour Pressure Deficit\VPD-Aus'
output_dir = r'Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland'
geojson_path = r'Data\QLD Bio Regions\QLD_BioRegions_Separated\New_England_Tableland.geojson' 

# save_filename = output_dir.split('/')[-1]  # Extract the last part of the output directory for naming

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Load the QLD boundary
qld_gdf = gpd.read_file(geojson_path)
qld_gdf = qld_gdf.to_crs("EPSG:4326")  # ensure it matches NetCDF projection (WGS84)

# Loop through .nc files
for filename in os.listdir(input_dir):
    if filename.endswith(".nc"):
        filepath = os.path.join(input_dir, filename)
        try:
            # Open dataset with rioxarray
            ds = xr.open_dataset(filepath)
            variable_name = list(ds.data_vars)[0]
            data = ds[variable_name]

            # Ensure it's georeferenced
            data.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
            data.rio.write_crs("EPSG:4326", inplace=True)

            # Clip to QLD geometry
            clipped = data.rio.clip(qld_gdf.geometry, qld_gdf.crs, drop=True)

            # Save to output
            output_filename = os.path.splitext(filename)[0] + "_" + os.path.basename(output_dir) + "_qld.nc"
            output_path = os.path.join(output_dir, output_filename)
            clipped.to_netcdf(output_path)

            print(f"✅ Cropped {filename} to QLD and saved to {output_path}")

        except Exception as e:
            print(f"❌ Error processing {filename}: {e}")
# Out:
# ✅ Cropped 2001.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2001.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2002.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2002.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2003.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2003.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2004.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2004.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2005.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2005.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2006.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2006.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2007.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2007.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2008.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2008.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2009.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2009.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2010.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2010.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2011.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2011.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2012.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2012.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2013.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2013.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2014.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2014.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2015.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2015.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2016.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2016.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2017.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2017.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2018.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2018.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2019.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2019.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2020.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2020.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2021.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2021.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2022.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2022.vp_deficit_New_England_Tableland_qld.nc
# ✅ Cropped 2023.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\New_England_Tableland\2023.vp_deficit_New_England_Tableland_qld.nc

# %%
# Paths
input_dir = r'Data\Data for SPI\Vapour Pressure Deficit\VPD-Aus'
output_dir = r'Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands'
geojson_path = r'Data\QLD Bio Regions\QLD_BioRegions_Separated\Northwest_Highlands.geojson' 

# save_filename = output_dir.split('/')[-1]  # Extract the last part of the output directory for naming

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Load the QLD boundary
qld_gdf = gpd.read_file(geojson_path)
qld_gdf = qld_gdf.to_crs("EPSG:4326")  # ensure it matches NetCDF projection (WGS84)

# Loop through .nc files
for filename in os.listdir(input_dir):
    if filename.endswith(".nc"):
        filepath = os.path.join(input_dir, filename)
        try:
            # Open dataset with rioxarray
            ds = xr.open_dataset(filepath)
            variable_name = list(ds.data_vars)[0]
            data = ds[variable_name]

            # Ensure it's georeferenced
            data.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
            data.rio.write_crs("EPSG:4326", inplace=True)

            # Clip to QLD geometry
            clipped = data.rio.clip(qld_gdf.geometry, qld_gdf.crs, drop=True)

            # Save to output
            output_filename = os.path.splitext(filename)[0] + "_" + os.path.basename(output_dir) + "_qld.nc"
            output_path = os.path.join(output_dir, output_filename)
            clipped.to_netcdf(output_path)

            print(f"✅ Cropped {filename} to QLD and saved to {output_path}")

        except Exception as e:
            print(f"❌ Error processing {filename}: {e}")
# Out:
# ✅ Cropped 2001.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2001.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2002.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2002.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2003.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2003.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2004.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2004.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2005.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2005.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2006.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2006.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2007.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2007.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2008.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2008.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2009.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2009.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2010.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2010.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2011.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2011.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2012.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2012.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2013.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2013.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2014.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2014.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2015.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2015.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2016.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2016.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2017.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2017.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2018.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2018.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2019.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2019.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2020.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2020.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2021.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2021.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2022.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2022.vp_deficit_Northwest_Highlands_qld.nc
# ✅ Cropped 2023.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Northwest_Highlands\2023.vp_deficit_Northwest_Highlands_qld.nc

# %%
# Paths
input_dir = r'Data\Data for SPI\Vapour Pressure Deficit\VPD-Aus'
output_dir = r'Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland'
geojson_path = r'Data\QLD Bio Regions\QLD_BioRegions_Separated\Southeast_Queensland.geojson' 

# save_filename = output_dir.split('/')[-1]  # Extract the last part of the output directory for naming

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Load the QLD boundary
qld_gdf = gpd.read_file(geojson_path)
qld_gdf = qld_gdf.to_crs("EPSG:4326")  # ensure it matches NetCDF projection (WGS84)

# Loop through .nc files
for filename in os.listdir(input_dir):
    if filename.endswith(".nc"):
        filepath = os.path.join(input_dir, filename)
        try:
            # Open dataset with rioxarray
            ds = xr.open_dataset(filepath)
            variable_name = list(ds.data_vars)[0]
            data = ds[variable_name]

            # Ensure it's georeferenced
            data.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
            data.rio.write_crs("EPSG:4326", inplace=True)

            # Clip to QLD geometry
            clipped = data.rio.clip(qld_gdf.geometry, qld_gdf.crs, drop=True)

            # Save to output
            output_filename = os.path.splitext(filename)[0] + "_" + os.path.basename(output_dir) + "_qld.nc"
            output_path = os.path.join(output_dir, output_filename)
            clipped.to_netcdf(output_path)

            print(f"✅ Cropped {filename} to QLD and saved to {output_path}")

        except Exception as e:
            print(f"❌ Error processing {filename}: {e}")
# Out:
# ✅ Cropped 2001.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2001.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2002.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2002.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2003.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2003.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2004.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2004.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2005.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2005.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2006.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2006.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2007.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2007.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2008.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2008.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2009.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2009.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2010.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2010.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2011.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2011.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2012.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2012.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2013.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2013.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2014.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2014.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2015.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2015.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2016.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2016.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2017.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2017.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2018.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2018.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2019.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2019.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2020.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2020.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2021.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2021.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2022.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2022.vp_deficit_Southeast_Queensland_qld.nc
# ✅ Cropped 2023.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Southeast_Queensland\2023.vp_deficit_Southeast_Queensland_qld.nc

# %%
# Paths
input_dir = r'Data\Data for SPI\Vapour Pressure Deficit\VPD-Aus'
output_dir = r'Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics'
geojson_path = r'Data\QLD Bio Regions\QLD_BioRegions_Separated\Wet_Tropics.geojson' 

# save_filename = output_dir.split('/')[-1]  # Extract the last part of the output directory for naming

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Load the QLD boundary
qld_gdf = gpd.read_file(geojson_path)
qld_gdf = qld_gdf.to_crs("EPSG:4326")  # ensure it matches NetCDF projection (WGS84)

# Loop through .nc files
for filename in os.listdir(input_dir):
    if filename.endswith(".nc"):
        filepath = os.path.join(input_dir, filename)
        try:
            # Open dataset with rioxarray
            ds = xr.open_dataset(filepath)
            variable_name = list(ds.data_vars)[0]
            data = ds[variable_name]

            # Ensure it's georeferenced
            data.rio.set_spatial_dims(x_dim="lon", y_dim="lat", inplace=True)
            data.rio.write_crs("EPSG:4326", inplace=True)

            # Clip to QLD geometry
            clipped = data.rio.clip(qld_gdf.geometry, qld_gdf.crs, drop=True)

            # Save to output
            output_filename = os.path.splitext(filename)[0] + "_" + os.path.basename(output_dir) + "_qld.nc"
            output_path = os.path.join(output_dir, output_filename)
            clipped.to_netcdf(output_path)

            print(f"✅ Cropped {filename} to QLD and saved to {output_path}")

        except Exception as e:
            print(f"❌ Error processing {filename}: {e}")
# Out:
# ✅ Cropped 2001.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2001.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2002.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2002.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2003.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2003.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2004.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2004.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2005.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2005.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2006.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2006.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2007.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2007.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2008.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2008.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2009.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2009.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2010.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2010.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2011.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2011.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2012.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2012.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2013.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2013.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2014.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2014.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2015.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2015.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2016.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2016.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2017.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2017.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2018.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2018.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2019.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2019.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2020.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2020.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2021.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2021.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2022.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2022.vp_deficit_Wet_Tropics_qld.nc
# ✅ Cropped 2023.vp_deficit.nc to QLD and saved to Data\Data for SPI\Vapour Pressure Deficit\Region Separated Monthly VPD\Wet_Tropics\2023.vp_deficit_Wet_Tropics_qld.nc
